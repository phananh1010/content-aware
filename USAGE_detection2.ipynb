# %%
import numpy as np
from PIL import Image
import predictor2


from matplotlib import pyplot as plt
# %matplotlib inline

# %%
image_path = '/home/u9167/testing/ssd2/demo/dog.jpg'
image_path = '/home/u9167/testing/ssd2/demo/herd_of_horses.jpg'
image = np.array(Image.open(image_path).convert("RGB"))
plt.imshow(image)

# %%
pred300 = predictor2.Predictor('300')
result300 = pred300.detect(image)


print (result300)
# Out:
# [[0, 13, 0.99736136, 0.007913097218739262, 0.37352454662323, 0.4301855326624151, 0.7867538928985596], [0, 13, 0.99605185, 0.5594829051028865, 0.41148608922958374, 0.7776075513674402, 0.6741278767585754], [0, 13, 0.8467931, 0.2948804413670864, 0.41346079111099243, 0.559696251793944, 0.6968405842781067], [0, 13, 0.5642771, -0.00038801875799161805, 0.3588736057281494, 0.19862284789881146, 0.5935439467430115]]

# %%
pred512 = predictor2.Predictor('512')

result512 = pred512.detect(image)


print (result512)
# Out:
# [[0, 13, 0.9985448, 0.007582127816618491, 0.3771340847015381, 0.4207039619633328, 0.7980220317840576], [0, 13, 0.9984345, 0.5646438499934306, 0.41957369446754456, 0.7734545551018758, 0.6843844652175903], [0, 13, 0.99175936, 0.3056638848426888, 0.39645954966545105, 0.584659867576609, 0.6990848779678345], [0, 13, 0.91181624, -0.00025183706511809633, 0.36630943417549133, 0.20841488461907745, 0.5694483518600464]]
